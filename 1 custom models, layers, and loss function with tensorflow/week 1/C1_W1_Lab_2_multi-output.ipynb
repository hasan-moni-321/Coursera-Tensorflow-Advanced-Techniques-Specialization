# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 917us/sample - loss: 268.9524 - y1_output_loss: 125.2359 - y2_output_loss: 141.1808 - y1_output_root_mean_squared_error: 11.2441 - y2_output_root_mean_squared_error: 11.9383 - val_loss: 43.3733 - val_y1_output_loss: 16.2912 - val_y2_output_loss: 25.5784 - val_y1_output_root_mean_squared_error: 4.1094 - val_y2_output_root_mean_squared_error: 5.1465
# Epoch 2/500
# 614/614 [==============================] - 0s 162us/sample - loss: 28.4464 - y1_output_loss: 11.8683 - y2_output_loss: 16.6379 - y1_output_root_mean_squared_error: 3.4510 - y2_output_root_mean_squared_error: 4.0666 - val_loss: 24.2595 - val_y1_output_loss: 10.2104 - val_y2_output_loss: 13.2847 - val_y1_output_root_mean_squared_error: 3.2484 - val_y2_output_root_mean_squared_error: 3.7023
# Epoch 3/500
# 614/614 [==============================] - 0s 127us/sample - loss: 27.2660 - y1_output_loss: 10.3450 - y2_output_loss: 16.9449 - y1_output_root_mean_squared_error: 3.2208 - y2_output_root_mean_squared_error: 4.1100 - val_loss: 46.1508 - val_y1_output_loss: 14.1476 - val_y2_output_loss: 30.9047 - val_y1_output_root_mean_squared_error: 3.8110 - val_y2_output_root_mean_squared_error: 5.6238
# Epoch 4/500
# 614/614 [==============================] - 0s 137us/sample - loss: 26.5698 - y1_output_loss: 9.6949 - y2_output_loss: 16.7273 - y1_output_root_mean_squared_error: 3.1226 - y2_output_root_mean_squared_error: 4.1011 - val_loss: 23.2395 - val_y1_output_loss: 9.4919 - val_y2_output_loss: 12.9406 - val_y1_output_root_mean_squared_error: 3.1344 - val_y2_output_root_mean_squared_error: 3.6627
# Epoch 5/500
# 614/614 [==============================] - 0s 136us/sample - loss: 28.7691 - y1_output_loss: 10.2069 - y2_output_loss: 18.6098 - y1_output_root_mean_squared_error: 3.1710 - y2_output_root_mean_squared_error: 4.3259 - val_loss: 28.3698 - val_y1_output_loss: 10.8516 - val_y2_output_loss: 16.6563 - val_y1_output_root_mean_squared_error: 3.3445 - val_y2_output_root_mean_squared_error: 4.1454
# Epoch 6/500
# 614/614 [==============================] - 0s 135us/sample - loss: 20.2374 - y1_output_loss: 8.4882 - y2_output_loss: 11.5886 - y1_output_root_mean_squared_error: 2.9231 - y2_output_root_mean_squared_error: 3.4195 - val_loss: 24.5422 - val_y1_output_loss: 9.2424 - val_y2_output_loss: 14.4777 - val_y1_output_root_mean_squared_error: 3.0922 - val_y2_output_root_mean_squared_error: 3.8705
# Epoch 7/500
# 614/614 [==============================] - 0s 141us/sample - loss: 20.4430 - y1_output_loss: 8.2063 - y2_output_loss: 12.1722 - y1_output_root_mean_squared_error: 2.8596 - y2_output_root_mean_squared_error: 3.5022 - val_loss: 21.1626 - val_y1_output_loss: 8.2065 - val_y2_output_loss: 12.2154 - val_y1_output_root_mean_squared_error: 2.9155 - val_y2_output_root_mean_squared_error: 3.5585
# Epoch 8/500
# 614/614 [==============================] - 0s 133us/sample - loss: 19.9455 - y1_output_loss: 8.0395 - y2_output_loss: 11.7639 - y1_output_root_mean_squared_error: 2.8471 - y2_output_root_mean_squared_error: 3.4408 - val_loss: 25.2839 - val_y1_output_loss: 8.6155 - val_y2_output_loss: 15.8733 - val_y1_output_root_mean_squared_error: 2.9834 - val_y2_output_root_mean_squared_error: 4.0476
# Epoch 9/500
# 614/614 [==============================] - 0s 124us/sample - loss: 21.7975 - y1_output_loss: 8.3585 - y2_output_loss: 13.4040 - y1_output_root_mean_squared_error: 2.8956 - y2_output_root_mean_squared_error: 3.6624 - val_loss: 35.4734 - val_y1_output_loss: 13.5218 - val_y2_output_loss: 21.2186 - val_y1_output_root_mean_squared_error: 3.7128 - val_y2_output_root_mean_squared_error: 4.6571
# Epoch 10/500
# 614/614 [==============================] - 0s 130us/sample - loss: 20.1290 - y1_output_loss: 8.0768 - y2_output_loss: 12.0469 - y1_output_root_mean_squared_error: 2.8448 - y2_output_root_mean_squared_error: 3.4693 - val_loss: 28.0860 - val_y1_output_loss: 9.2696 - val_y2_output_loss: 17.9168 - val_y1_output_root_mean_squared_error: 3.0952 - val_y2_output_root_mean_squared_error: 4.3019
# Epoch 11/500
# 614/614 [==============================] - 0s 136us/sample - loss: 20.4852 - y1_output_loss: 7.8394 - y2_output_loss: 12.4953 - y1_output_root_mean_squared_error: 2.8103 - y2_output_root_mean_squared_error: 3.5478 - val_loss: 19.8954 - val_y1_output_loss: 7.8260 - val_y2_output_loss: 11.3718 - val_y1_output_root_mean_squared_error: 2.8449 - val_y2_output_root_mean_squared_error: 3.4354
# Epoch 12/500
# 614/614 [==============================] - 0s 133us/sample - loss: 20.5260 - y1_output_loss: 7.9548 - y2_output_loss: 12.4415 - y1_output_root_mean_squared_error: 2.8298 - y2_output_root_mean_squared_error: 3.5381 - val_loss: 20.4375 - val_y1_output_loss: 7.8837 - val_y2_output_loss: 11.8472 - val_y1_output_root_mean_squared_error: 2.8538 - val_y2_output_root_mean_squared_error: 3.5062
# Epoch 13/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.6483 - y1_output_loss: 7.5931 - y2_output_loss: 10.9865 - y1_output_root_mean_squared_error: 2.7593 - y2_output_root_mean_squared_error: 3.3218 - val_loss: 26.8915 - val_y1_output_loss: 9.6418 - val_y2_output_loss: 16.4786 - val_y1_output_root_mean_squared_error: 3.1518 - val_y2_output_root_mean_squared_error: 4.1180
# Epoch 14/500
# 614/614 [==============================] - 0s 129us/sample - loss: 20.3558 - y1_output_loss: 7.9129 - y2_output_loss: 13.3832 - y1_output_root_mean_squared_error: 2.7815 - y2_output_root_mean_squared_error: 3.5523 - val_loss: 176.5580 - val_y1_output_loss: 37.3742 - val_y2_output_loss: 136.4030 - val_y1_output_root_mean_squared_error: 6.1662 - val_y2_output_root_mean_squared_error: 11.7701
# Epoch 15/500
# 614/614 [==============================] - 0s 134us/sample - loss: 22.3343 - y1_output_loss: 7.6785 - y2_output_loss: 14.4508 - y1_output_root_mean_squared_error: 2.7831 - y2_output_root_mean_squared_error: 3.8195 - val_loss: 18.1529 - val_y1_output_loss: 6.8826 - val_y2_output_loss: 10.6297 - val_y1_output_root_mean_squared_error: 2.6681 - val_y2_output_root_mean_squared_error: 3.3218
# Epoch 16/500
# 614/614 [==============================] - 0s 131us/sample - loss: 16.2842 - y1_output_loss: 6.2627 - y2_output_loss: 10.0497 - y1_output_root_mean_squared_error: 2.5072 - y2_output_root_mean_squared_error: 3.1620 - val_loss: 41.3838 - val_y1_output_loss: 10.0247 - val_y2_output_loss: 30.4566 - val_y1_output_root_mean_squared_error: 3.2074 - val_y2_output_root_mean_squared_error: 5.5764
# Epoch 17/500
# 614/614 [==============================] - 0s 136us/sample - loss: 16.7059 - y1_output_loss: 6.4322 - y2_output_loss: 10.3175 - y1_output_root_mean_squared_error: 2.5333 - y2_output_root_mean_squared_error: 3.2075 - val_loss: 24.6361 - val_y1_output_loss: 7.5744 - val_y2_output_loss: 16.3798 - val_y1_output_root_mean_squared_error: 2.7941 - val_y2_output_root_mean_squared_error: 4.1023
# Epoch 18/500
# 614/614 [==============================] - 0s 132us/sample - loss: 17.4629 - y1_output_loss: 6.5252 - y2_output_loss: 10.7846 - y1_output_root_mean_squared_error: 2.5646 - y2_output_root_mean_squared_error: 3.2994 - val_loss: 16.2868 - val_y1_output_loss: 6.4120 - val_y2_output_loss: 9.2961 - val_y1_output_root_mean_squared_error: 2.5758 - val_y2_output_root_mean_squared_error: 3.1067
# Epoch 19/500
# 614/614 [==============================] - 0s 143us/sample - loss: 14.9333 - y1_output_loss: 5.9393 - y2_output_loss: 8.9224 - y1_output_root_mean_squared_error: 2.4480 - y2_output_root_mean_squared_error: 2.9901 - val_loss: 22.0406 - val_y1_output_loss: 6.3679 - val_y2_output_loss: 14.9981 - val_y1_output_root_mean_squared_error: 2.5667 - val_y2_output_root_mean_squared_error: 3.9310
# Epoch 20/500
# 614/614 [==============================] - 0s 143us/sample - loss: 14.7719 - y1_output_loss: 5.6676 - y2_output_loss: 9.2119 - y1_output_root_mean_squared_error: 2.3674 - y2_output_root_mean_squared_error: 3.0278 - val_loss: 23.1071 - val_y1_output_loss: 7.7366 - val_y2_output_loss: 14.8223 - val_y1_output_root_mean_squared_error: 2.8146 - val_y2_output_root_mean_squared_error: 3.8968
# Epoch 21/500
# 614/614 [==============================] - 0s 131us/sample - loss: 15.5609 - y1_output_loss: 5.9714 - y2_output_loss: 9.5165 - y1_output_root_mean_squared_error: 2.4480 - y2_output_root_mean_squared_error: 3.0932 - val_loss: 18.8133 - val_y1_output_loss: 6.8523 - val_y2_output_loss: 11.3466 - val_y1_output_root_mean_squared_error: 2.6605 - val_y2_output_root_mean_squared_error: 3.4257
# Epoch 22/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.1274 - y1_output_loss: 5.4412 - y2_output_loss: 8.5907 - y1_output_root_mean_squared_error: 2.3353 - y2_output_root_mean_squared_error: 2.9452 - val_loss: 14.7285 - val_y1_output_loss: 5.5249 - val_y2_output_loss: 8.7256 - val_y1_output_root_mean_squared_error: 2.3914 - val_y2_output_root_mean_squared_error: 3.0016
# Epoch 23/500
# 614/614 [==============================] - 0s 141us/sample - loss: 13.6124 - y1_output_loss: 5.3576 - y2_output_loss: 8.8286 - y1_output_root_mean_squared_error: 2.2532 - y2_output_root_mean_squared_error: 2.9216 - val_loss: 86.9653 - val_y1_output_loss: 24.3851 - val_y2_output_loss: 61.0573 - val_y1_output_root_mean_squared_error: 4.9862 - val_y2_output_root_mean_squared_error: 7.8805
# Epoch 24/500
# 614/614 [==============================] - 0s 143us/sample - loss: 14.7111 - y1_output_loss: 5.1038 - y2_output_loss: 9.5154 - y1_output_root_mean_squared_error: 2.2669 - y2_output_root_mean_squared_error: 3.0939 - val_loss: 14.1011 - val_y1_output_loss: 5.5942 - val_y2_output_loss: 7.9915 - val_y1_output_root_mean_squared_error: 2.4085 - val_y2_output_root_mean_squared_error: 2.8810
# Epoch 25/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.0353 - y1_output_loss: 4.8650 - y2_output_loss: 8.1482 - y1_output_root_mean_squared_error: 2.2116 - y2_output_root_mean_squared_error: 2.8538 - val_loss: 13.5459 - val_y1_output_loss: 5.2011 - val_y2_output_loss: 7.8800 - val_y1_output_root_mean_squared_error: 2.3225 - val_y2_output_root_mean_squared_error: 2.8551
# Epoch 26/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.9792 - y1_output_loss: 4.9309 - y2_output_loss: 10.2366 - y1_output_root_mean_squared_error: 2.1946 - y2_output_root_mean_squared_error: 3.1880 - val_loss: 13.9583 - val_y1_output_loss: 5.6094 - val_y2_output_loss: 8.0127 - val_y1_output_root_mean_squared_error: 2.3928 - val_y2_output_root_mean_squared_error: 2.8693
# Epoch 27/500
# 614/614 [==============================] - 0s 128us/sample - loss: 14.6242 - y1_output_loss: 4.7896 - y2_output_loss: 9.7508 - y1_output_root_mean_squared_error: 2.1978 - y2_output_root_mean_squared_error: 3.1295 - val_loss: 15.7643 - val_y1_output_loss: 4.7514 - val_y2_output_loss: 10.5291 - val_y1_output_root_mean_squared_error: 2.2176 - val_y2_output_root_mean_squared_error: 3.2934
# Epoch 28/500
# 614/614 [==============================] - 0s 139us/sample - loss: 12.7963 - y1_output_loss: 4.4355 - y2_output_loss: 8.3312 - y1_output_root_mean_squared_error: 2.1006 - y2_output_root_mean_squared_error: 2.8955 - val_loss: 11.9755 - val_y1_output_loss: 4.4564 - val_y2_output_loss: 7.1214 - val_y1_output_root_mean_squared_error: 2.1488 - val_y2_output_root_mean_squared_error: 2.7126
# Epoch 29/500
# 614/614 [==============================] - 0s 130us/sample - loss: 11.1180 - y1_output_loss: 3.9967 - y2_output_loss: 7.1543 - y1_output_root_mean_squared_error: 1.9993 - y2_output_root_mean_squared_error: 2.6685 - val_loss: 12.0703 - val_y1_output_loss: 4.5412 - val_y2_output_loss: 7.1080 - val_y1_output_root_mean_squared_error: 2.1683 - val_y2_output_root_mean_squared_error: 2.7145
# Epoch 30/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.5296 - y1_output_loss: 3.7451 - y2_output_loss: 6.7042 - y1_output_root_mean_squared_error: 1.9424 - y2_output_root_mean_squared_error: 2.5994 - val_loss: 11.3005 - val_y1_output_loss: 4.1667 - val_y2_output_loss: 6.7846 - val_y1_output_root_mean_squared_error: 2.0721 - val_y2_output_root_mean_squared_error: 2.6470
# Epoch 31/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.1716 - y1_output_loss: 3.3560 - y2_output_loss: 5.8280 - y1_output_root_mean_squared_error: 1.8377 - y2_output_root_mean_squared_error: 2.4072 - val_loss: 16.3364 - val_y1_output_loss: 4.7261 - val_y2_output_loss: 11.1222 - val_y1_output_root_mean_squared_error: 2.2108 - val_y2_output_root_mean_squared_error: 3.3836
# Epoch 32/500
# 614/614 [==============================] - 0s 135us/sample - loss: 10.0282 - y1_output_loss: 3.4336 - y2_output_loss: 6.5111 - y1_output_root_mean_squared_error: 1.8605 - y2_output_root_mean_squared_error: 2.5626 - val_loss: 10.1790 - val_y1_output_loss: 3.6276 - val_y2_output_loss: 6.1772 - val_y1_output_root_mean_squared_error: 1.9407 - val_y2_output_root_mean_squared_error: 2.5324
# Epoch 33/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.1783 - y1_output_loss: 3.2425 - y2_output_loss: 5.8535 - y1_output_root_mean_squared_error: 1.8084 - y2_output_root_mean_squared_error: 2.4306 - val_loss: 10.2328 - val_y1_output_loss: 3.5856 - val_y2_output_loss: 6.3026 - val_y1_output_root_mean_squared_error: 1.9257 - val_y2_output_root_mean_squared_error: 2.5543
# Epoch 34/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.6398 - y1_output_loss: 3.1042 - y2_output_loss: 5.4578 - y1_output_root_mean_squared_error: 1.7701 - y2_output_root_mean_squared_error: 2.3466 - val_loss: 9.4498 - val_y1_output_loss: 3.4808 - val_y2_output_loss: 5.6252 - val_y1_output_root_mean_squared_error: 1.9003 - val_y2_output_root_mean_squared_error: 2.4163
# Epoch 35/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.7556 - y1_output_loss: 3.4840 - y2_output_loss: 7.1802 - y1_output_root_mean_squared_error: 1.8742 - y2_output_root_mean_squared_error: 2.6913 - val_loss: 11.9972 - val_y1_output_loss: 4.2619 - val_y2_output_loss: 7.3736 - val_y1_output_root_mean_squared_error: 2.0957 - val_y2_output_root_mean_squared_error: 2.7577
# Epoch 36/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.9931 - y1_output_loss: 2.6307 - y2_output_loss: 5.2943 - y1_output_root_mean_squared_error: 1.6284 - y2_output_root_mean_squared_error: 2.3112 - val_loss: 8.8057 - val_y1_output_loss: 3.2243 - val_y2_output_loss: 5.2695 - val_y1_output_root_mean_squared_error: 1.8278 - val_y2_output_root_mean_squared_error: 2.3377
# Epoch 37/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.9436 - y1_output_loss: 3.3124 - y2_output_loss: 6.6005 - y1_output_root_mean_squared_error: 1.8231 - y2_output_root_mean_squared_error: 2.5729 - val_loss: 9.6085 - val_y1_output_loss: 3.3825 - val_y2_output_loss: 5.8796 - val_y1_output_root_mean_squared_error: 1.8735 - val_y2_output_root_mean_squared_error: 2.4695
# Epoch 38/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.4258 - y1_output_loss: 3.0088 - y2_output_loss: 6.3485 - y1_output_root_mean_squared_error: 1.7374 - y2_output_root_mean_squared_error: 2.5312 - val_loss: 14.2994 - val_y1_output_loss: 5.1932 - val_y2_output_loss: 8.7842 - val_y1_output_root_mean_squared_error: 2.3041 - val_y2_output_root_mean_squared_error: 2.9984
# Epoch 39/500
# 614/614 [==============================] - 0s 125us/sample - loss: 9.3982 - y1_output_loss: 3.2636 - y2_output_loss: 6.1090 - y1_output_root_mean_squared_error: 1.8081 - y2_output_root_mean_squared_error: 2.4757 - val_loss: 11.9213 - val_y1_output_loss: 4.0423 - val_y2_output_loss: 7.5606 - val_y1_output_root_mean_squared_error: 2.0369 - val_y2_output_root_mean_squared_error: 2.7879
# Epoch 40/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.2202 - y1_output_loss: 2.9603 - y2_output_loss: 5.2912 - y1_output_root_mean_squared_error: 1.7037 - y2_output_root_mean_squared_error: 2.3060 - val_loss: 8.2712 - val_y1_output_loss: 2.6594 - val_y2_output_loss: 5.3168 - val_y1_output_root_mean_squared_error: 1.6615 - val_y2_output_root_mean_squared_error: 2.3475
# Epoch 41/500
# 614/614 [==============================] - 0s 142us/sample - loss: 9.1414 - y1_output_loss: 3.1498 - y2_output_loss: 5.9518 - y1_output_root_mean_squared_error: 1.7808 - y2_output_root_mean_squared_error: 2.4434 - val_loss: 12.1986 - val_y1_output_loss: 3.6686 - val_y2_output_loss: 8.3050 - val_y1_output_root_mean_squared_error: 1.9313 - val_y2_output_root_mean_squared_error: 2.9101
# Epoch 42/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.8701 - y1_output_loss: 2.6785 - y2_output_loss: 5.2231 - y1_output_root_mean_squared_error: 1.6202 - y2_output_root_mean_squared_error: 2.2902 - val_loss: 7.8121 - val_y1_output_loss: 2.9674 - val_y2_output_loss: 4.5714 - val_y1_output_root_mean_squared_error: 1.7526 - val_y2_output_root_mean_squared_error: 2.1773
# Epoch 43/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.8042 - y1_output_loss: 2.3080 - y2_output_loss: 4.4377 - y1_output_root_mean_squared_error: 1.5265 - y2_output_root_mean_squared_error: 2.1152 - val_loss: 9.3459 - val_y1_output_loss: 2.8448 - val_y2_output_loss: 6.2326 - val_y1_output_root_mean_squared_error: 1.7128 - val_y2_output_root_mean_squared_error: 2.5322
# Epoch 44/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.4372 - y1_output_loss: 2.8403 - y2_output_loss: 5.6131 - y1_output_root_mean_squared_error: 1.6925 - y2_output_root_mean_squared_error: 2.3607 - val_loss: 19.3973 - val_y1_output_loss: 3.5704 - val_y2_output_loss: 15.3761 - val_y1_output_root_mean_squared_error: 1.9176 - val_y2_output_root_mean_squared_error: 3.9649
# Epoch 45/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.0374 - y1_output_loss: 3.5095 - y2_output_loss: 7.4426 - y1_output_root_mean_squared_error: 1.8805 - y2_output_root_mean_squared_error: 2.7388 - val_loss: 7.9932 - val_y1_output_loss: 2.9639 - val_y2_output_loss: 4.7351 - val_y1_output_root_mean_squared_error: 1.7539 - val_y2_output_root_mean_squared_error: 2.2174
# Epoch 46/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.8335 - y1_output_loss: 2.3314 - y2_output_loss: 5.4472 - y1_output_root_mean_squared_error: 1.5292 - y2_output_root_mean_squared_error: 2.3442 - val_loss: 8.0373 - val_y1_output_loss: 2.8460 - val_y2_output_loss: 4.8978 - val_y1_output_root_mean_squared_error: 1.7181 - val_y2_output_root_mean_squared_error: 2.2551
# Epoch 47/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.0596 - y1_output_loss: 2.4131 - y2_output_loss: 4.5926 - y1_output_root_mean_squared_error: 1.5574 - y2_output_root_mean_squared_error: 2.1527 - val_loss: 7.0663 - val_y1_output_loss: 2.3117 - val_y2_output_loss: 4.5286 - val_y1_output_root_mean_squared_error: 1.5426 - val_y2_output_root_mean_squared_error: 2.1649
# Epoch 48/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.3656 - y1_output_loss: 2.4307 - y2_output_loss: 4.8786 - y1_output_root_mean_squared_error: 1.5638 - y2_output_root_mean_squared_error: 2.2182 - val_loss: 7.1958 - val_y1_output_loss: 2.5693 - val_y2_output_loss: 4.4259 - val_y1_output_root_mean_squared_error: 1.6193 - val_y2_output_root_mean_squared_error: 2.1386
# Epoch 49/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.5198 - y1_output_loss: 3.8664 - y2_output_loss: 8.5526 - y1_output_root_mean_squared_error: 1.9727 - y2_output_root_mean_squared_error: 2.9374 - val_loss: 9.7187 - val_y1_output_loss: 3.2446 - val_y2_output_loss: 6.3495 - val_y1_output_root_mean_squared_error: 1.8068 - val_y2_output_root_mean_squared_error: 2.5405
# Epoch 50/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.9236 - y1_output_loss: 2.2025 - y2_output_loss: 4.7488 - y1_output_root_mean_squared_error: 1.4831 - y2_output_root_mean_squared_error: 2.1735 - val_loss: 7.7487 - val_y1_output_loss: 2.5609 - val_y2_output_loss: 4.9365 - val_y1_output_root_mean_squared_error: 1.6264 - val_y2_output_root_mean_squared_error: 2.2591
# Epoch 51/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.6595 - y1_output_loss: 1.9613 - y2_output_loss: 4.7497 - y1_output_root_mean_squared_error: 1.4064 - y2_output_root_mean_squared_error: 2.1637 - val_loss: 30.0487 - val_y1_output_loss: 5.8184 - val_y2_output_loss: 23.7175 - val_y1_output_root_mean_squared_error: 2.4333 - val_y2_output_root_mean_squared_error: 4.9120
# Epoch 52/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.5442 - y1_output_loss: 2.7388 - y2_output_loss: 5.7870 - y1_output_root_mean_squared_error: 1.6538 - y2_output_root_mean_squared_error: 2.4102 - val_loss: 10.3964 - val_y1_output_loss: 3.1303 - val_y2_output_loss: 6.9209 - val_y1_output_root_mean_squared_error: 1.8011 - val_y2_output_root_mean_squared_error: 2.6744
# Epoch 53/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.8182 - y1_output_loss: 2.1624 - y2_output_loss: 4.7164 - y1_output_root_mean_squared_error: 1.4730 - y2_output_root_mean_squared_error: 2.1561 - val_loss: 9.1565 - val_y1_output_loss: 2.5553 - val_y2_output_loss: 6.3005 - val_y1_output_root_mean_squared_error: 1.6284 - val_y2_output_root_mean_squared_error: 2.5504
# Epoch 54/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.5567 - y1_output_loss: 2.0102 - y2_output_loss: 4.5813 - y1_output_root_mean_squared_error: 1.4164 - y2_output_root_mean_squared_error: 2.1332 - val_loss: 8.8145 - val_y1_output_loss: 2.8281 - val_y2_output_loss: 5.6718 - val_y1_output_root_mean_squared_error: 1.7134 - val_y2_output_root_mean_squared_error: 2.4246
# Epoch 55/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.5441 - y1_output_loss: 2.4311 - y2_output_loss: 5.0472 - y1_output_root_mean_squared_error: 1.5660 - y2_output_root_mean_squared_error: 2.2565 - val_loss: 6.8512 - val_y1_output_loss: 2.4569 - val_y2_output_loss: 4.1685 - val_y1_output_root_mean_squared_error: 1.5903 - val_y2_output_root_mean_squared_error: 2.0790
# Epoch 56/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.1919 - y1_output_loss: 2.2438 - y2_output_loss: 4.9176 - y1_output_root_mean_squared_error: 1.5035 - y2_output_root_mean_squared_error: 2.2207 - val_loss: 6.9338 - val_y1_output_loss: 2.4007 - val_y2_output_loss: 4.2912 - val_y1_output_root_mean_squared_error: 1.5773 - val_y2_output_root_mean_squared_error: 2.1085
# Epoch 57/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.4838 - y1_output_loss: 1.8753 - y2_output_loss: 4.6895 - y1_output_root_mean_squared_error: 1.3591 - y2_output_root_mean_squared_error: 2.1533 - val_loss: 9.4216 - val_y1_output_loss: 2.1192 - val_y2_output_loss: 7.0653 - val_y1_output_root_mean_squared_error: 1.4774 - val_y2_output_root_mean_squared_error: 2.6905
# Epoch 58/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.7690 - y1_output_loss: 2.0813 - y2_output_loss: 3.7462 - y1_output_root_mean_squared_error: 1.4155 - y2_output_root_mean_squared_error: 1.9405 - val_loss: 6.3994 - val_y1_output_loss: 2.0147 - val_y2_output_loss: 4.1954 - val_y1_output_root_mean_squared_error: 1.4366 - val_y2_output_root_mean_squared_error: 2.0822
# Epoch 59/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.4532 - y1_output_loss: 2.7338 - y2_output_loss: 5.7683 - y1_output_root_mean_squared_error: 1.6439 - y2_output_root_mean_squared_error: 2.3981 - val_loss: 12.1321 - val_y1_output_loss: 3.5769 - val_y2_output_loss: 8.3210 - val_y1_output_root_mean_squared_error: 1.9063 - val_y2_output_root_mean_squared_error: 2.9151
# Epoch 60/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.0142 - y1_output_loss: 2.1347 - y2_output_loss: 4.8398 - y1_output_root_mean_squared_error: 1.4602 - y2_output_root_mean_squared_error: 2.2095 - val_loss: 6.4945 - val_y1_output_loss: 2.1433 - val_y2_output_loss: 4.1238 - val_y1_output_root_mean_squared_error: 1.4899 - val_y2_output_root_mean_squared_error: 2.0675
# Epoch 61/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.8653 - y1_output_loss: 2.1889 - y2_output_loss: 4.7168 - y1_output_root_mean_squared_error: 1.4843 - y2_output_root_mean_squared_error: 2.1592 - val_loss: 6.9135 - val_y1_output_loss: 1.9644 - val_y2_output_loss: 4.7286 - val_y1_output_root_mean_squared_error: 1.4214 - val_y2_output_root_mean_squared_error: 2.2120
# Epoch 62/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.5635 - y1_output_loss: 1.7074 - y2_output_loss: 3.8450 - y1_output_root_mean_squared_error: 1.3026 - y2_output_root_mean_squared_error: 1.9664 - val_loss: 6.5371 - val_y1_output_loss: 2.4163 - val_y2_output_loss: 3.9109 - val_y1_output_root_mean_squared_error: 1.5765 - val_y2_output_root_mean_squared_error: 2.0129
# Epoch 63/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.1119 - y1_output_loss: 1.6379 - y2_output_loss: 3.4797 - y1_output_root_mean_squared_error: 1.2683 - y2_output_root_mean_squared_error: 1.8717 - val_loss: 6.9916 - val_y1_output_loss: 2.9107 - val_y2_output_loss: 3.9341 - val_y1_output_root_mean_squared_error: 1.7109 - val_y2_output_root_mean_squared_error: 2.0160
# Epoch 64/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.1569 - y1_output_loss: 2.1271 - y2_output_loss: 5.0265 - y1_output_root_mean_squared_error: 1.4534 - y2_output_root_mean_squared_error: 2.2460 - val_loss: 6.8032 - val_y1_output_loss: 1.7995 - val_y2_output_loss: 4.8985 - val_y1_output_root_mean_squared_error: 1.3496 - val_y2_output_root_mean_squared_error: 2.2320
# Epoch 65/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.4939 - y1_output_loss: 1.6867 - y2_output_loss: 3.8760 - y1_output_root_mean_squared_error: 1.2912 - y2_output_root_mean_squared_error: 1.9562 - val_loss: 12.1224 - val_y1_output_loss: 2.2813 - val_y2_output_loss: 9.4876 - val_y1_output_root_mean_squared_error: 1.5382 - val_y2_output_root_mean_squared_error: 3.1235
# Epoch 66/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.0451 - y1_output_loss: 1.7390 - y2_output_loss: 4.2708 - y1_output_root_mean_squared_error: 1.3219 - y2_output_root_mean_squared_error: 2.0731 - val_loss: 9.4879 - val_y1_output_loss: 2.4311 - val_y2_output_loss: 6.7414 - val_y1_output_root_mean_squared_error: 1.5882 - val_y2_output_root_mean_squared_error: 2.6392
# Epoch 67/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.0400 - y1_output_loss: 1.8674 - y2_output_loss: 4.1669 - y1_output_root_mean_squared_error: 1.3615 - y2_output_root_mean_squared_error: 2.0461 - val_loss: 6.5529 - val_y1_output_loss: 1.6031 - val_y2_output_loss: 4.7299 - val_y1_output_root_mean_squared_error: 1.2890 - val_y2_output_root_mean_squared_error: 2.2116
# Epoch 68/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.5796 - y1_output_loss: 1.7555 - y2_output_loss: 3.8104 - y1_output_root_mean_squared_error: 1.3274 - y2_output_root_mean_squared_error: 1.9539 - val_loss: 5.2582 - val_y1_output_loss: 1.6423 - val_y2_output_loss: 3.4291 - val_y1_output_root_mean_squared_error: 1.3046 - val_y2_output_root_mean_squared_error: 1.8858
# Epoch 69/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.9582 - y1_output_loss: 1.7800 - y2_output_loss: 4.1709 - y1_output_root_mean_squared_error: 1.3304 - y2_output_root_mean_squared_error: 2.0465 - val_loss: 5.1410 - val_y1_output_loss: 1.6017 - val_y2_output_loss: 3.3832 - val_y1_output_root_mean_squared_error: 1.2786 - val_y2_output_root_mean_squared_error: 1.8725
# Epoch 70/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.3003 - y1_output_loss: 1.4009 - y2_output_loss: 3.8617 - y1_output_root_mean_squared_error: 1.1841 - y2_output_root_mean_squared_error: 1.9744 - val_loss: 5.0539 - val_y1_output_loss: 1.4220 - val_y2_output_loss: 3.4627 - val_y1_output_root_mean_squared_error: 1.2089 - val_y2_output_root_mean_squared_error: 1.8954
# Epoch 71/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.0125 - y1_output_loss: 1.3944 - y2_output_loss: 3.6020 - y1_output_root_mean_squared_error: 1.1813 - y2_output_root_mean_squared_error: 1.9019 - val_loss: 4.8645 - val_y1_output_loss: 1.3331 - val_y2_output_loss: 3.3580 - val_y1_output_root_mean_squared_error: 1.1735 - val_y2_output_root_mean_squared_error: 1.8674
# Epoch 72/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.0000 - y1_output_loss: 1.2133 - y2_output_loss: 2.7567 - y1_output_root_mean_squared_error: 1.1060 - y2_output_root_mean_squared_error: 1.6664 - val_loss: 5.1005 - val_y1_output_loss: 1.4781 - val_y2_output_loss: 3.4411 - val_y1_output_root_mean_squared_error: 1.2380 - val_y2_output_root_mean_squared_error: 1.8889
# Epoch 73/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.8639 - y1_output_loss: 1.3231 - y2_output_loss: 3.5237 - y1_output_root_mean_squared_error: 1.1496 - y2_output_root_mean_squared_error: 1.8821 - val_loss: 5.7293 - val_y1_output_loss: 1.7194 - val_y2_output_loss: 3.8038 - val_y1_output_root_mean_squared_error: 1.3352 - val_y2_output_root_mean_squared_error: 1.9866
# Epoch 74/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.9708 - y1_output_loss: 1.1163 - y2_output_loss: 2.8861 - y1_output_root_mean_squared_error: 1.0586 - y2_output_root_mean_squared_error: 1.6883 - val_loss: 11.7808 - val_y1_output_loss: 1.8890 - val_y2_output_loss: 9.6566 - val_y1_output_root_mean_squared_error: 1.3910 - val_y2_output_root_mean_squared_error: 3.1378
# Epoch 75/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.3573 - y1_output_loss: 1.5501 - y2_output_loss: 3.8603 - y1_output_root_mean_squared_error: 1.2486 - y2_output_root_mean_squared_error: 1.9489 - val_loss: 35.9197 - val_y1_output_loss: 5.1260 - val_y2_output_loss: 30.2244 - val_y1_output_root_mean_squared_error: 2.2815 - val_y2_output_root_mean_squared_error: 5.5421
# Epoch 76/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.4740 - y1_output_loss: 1.5394 - y2_output_loss: 3.8920 - y1_output_root_mean_squared_error: 1.2450 - y2_output_root_mean_squared_error: 1.9809 - val_loss: 4.0592 - val_y1_output_loss: 1.2144 - val_y2_output_loss: 2.7155 - val_y1_output_root_mean_squared_error: 1.1156 - val_y2_output_root_mean_squared_error: 1.6777
# Epoch 77/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.7548 - y1_output_loss: 1.0717 - y2_output_loss: 2.7006 - y1_output_root_mean_squared_error: 1.0344 - y2_output_root_mean_squared_error: 1.6385 - val_loss: 6.0979 - val_y1_output_loss: 1.8285 - val_y2_output_loss: 4.1375 - val_y1_output_root_mean_squared_error: 1.3636 - val_y2_output_root_mean_squared_error: 2.0588
# Epoch 78/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.9513 - y1_output_loss: 1.2282 - y2_output_loss: 3.6806 - y1_output_root_mean_squared_error: 1.1126 - y2_output_root_mean_squared_error: 1.9270 - val_loss: 4.5443 - val_y1_output_loss: 1.2997 - val_y2_output_loss: 3.1253 - val_y1_output_root_mean_squared_error: 1.1456 - val_y2_output_root_mean_squared_error: 1.7978
# Epoch 79/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.3874 - y1_output_loss: 1.3953 - y2_output_loss: 3.9694 - y1_output_root_mean_squared_error: 1.1845 - y2_output_root_mean_squared_error: 1.9961 - val_loss: 3.8305 - val_y1_output_loss: 1.1421 - val_y2_output_loss: 2.5677 - val_y1_output_root_mean_squared_error: 1.0797 - val_y2_output_root_mean_squared_error: 1.6324
# Epoch 80/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0345 - y1_output_loss: 0.8228 - y2_output_loss: 2.1987 - y1_output_root_mean_squared_error: 0.9053 - y2_output_root_mean_squared_error: 1.4882 - val_loss: 6.5011 - val_y1_output_loss: 1.4616 - val_y2_output_loss: 4.8382 - val_y1_output_root_mean_squared_error: 1.2302 - val_y2_output_root_mean_squared_error: 2.2333
# Epoch 81/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.7390 - y1_output_loss: 1.0592 - y2_output_loss: 2.6580 - y1_output_root_mean_squared_error: 1.0299 - y2_output_root_mean_squared_error: 1.6365 - val_loss: 4.7852 - val_y1_output_loss: 1.0314 - val_y2_output_loss: 3.5934 - val_y1_output_root_mean_squared_error: 1.0339 - val_y2_output_root_mean_squared_error: 1.9277
# Epoch 82/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.7599 - y1_output_loss: 0.9113 - y2_output_loss: 2.8258 - y1_output_root_mean_squared_error: 0.9571 - y2_output_root_mean_squared_error: 1.6864 - val_loss: 3.5200 - val_y1_output_loss: 1.0614 - val_y2_output_loss: 2.3517 - val_y1_output_root_mean_squared_error: 1.0420 - val_y2_output_root_mean_squared_error: 1.5602
# Epoch 83/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.5851 - y1_output_loss: 1.2175 - y2_output_loss: 3.3668 - y1_output_root_mean_squared_error: 1.1080 - y2_output_root_mean_squared_error: 1.8323 - val_loss: 3.4486 - val_y1_output_loss: 0.9472 - val_y2_output_loss: 2.3875 - val_y1_output_root_mean_squared_error: 0.9860 - val_y2_output_root_mean_squared_error: 1.5736
# Epoch 84/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.9149 - y1_output_loss: 0.9881 - y2_output_loss: 2.9030 - y1_output_root_mean_squared_error: 0.9965 - y2_output_root_mean_squared_error: 1.7094 - val_loss: 3.3423 - val_y1_output_loss: 1.0036 - val_y2_output_loss: 2.2232 - val_y1_output_root_mean_squared_error: 1.0185 - val_y2_output_root_mean_squared_error: 1.5182
# Epoch 85/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.1851 - y1_output_loss: 0.8888 - y2_output_loss: 2.3019 - y1_output_root_mean_squared_error: 0.9433 - y2_output_root_mean_squared_error: 1.5150 - val_loss: 8.9945 - val_y1_output_loss: 1.4502 - val_y2_output_loss: 7.3617 - val_y1_output_root_mean_squared_error: 1.2156 - val_y2_output_root_mean_squared_error: 2.7417
# Epoch 86/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.5479 - y1_output_loss: 1.1129 - y2_output_loss: 3.4104 - y1_output_root_mean_squared_error: 1.0570 - y2_output_root_mean_squared_error: 1.8522 - val_loss: 4.4719 - val_y1_output_loss: 0.8821 - val_y2_output_loss: 3.5057 - val_y1_output_root_mean_squared_error: 0.9440 - val_y2_output_root_mean_squared_error: 1.8923
# Epoch 87/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.3970 - y1_output_loss: 0.8086 - y2_output_loss: 2.5704 - y1_output_root_mean_squared_error: 0.8967 - y2_output_root_mean_squared_error: 1.6102 - val_loss: 4.5153 - val_y1_output_loss: 1.0670 - val_y2_output_loss: 3.3114 - val_y1_output_root_mean_squared_error: 1.0493 - val_y2_output_root_mean_squared_error: 1.8477
# Epoch 88/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0214 - y1_output_loss: 0.7773 - y2_output_loss: 2.2384 - y1_output_root_mean_squared_error: 0.8816 - y2_output_root_mean_squared_error: 1.4980 - val_loss: 7.6775 - val_y1_output_loss: 1.7840 - val_y2_output_loss: 5.6602 - val_y1_output_root_mean_squared_error: 1.3584 - val_y2_output_root_mean_squared_error: 2.4150
# Epoch 89/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.0018 - y1_output_loss: 0.7515 - y2_output_loss: 2.3215 - y1_output_root_mean_squared_error: 0.8455 - y2_output_root_mean_squared_error: 1.5122 - val_loss: 14.8018 - val_y1_output_loss: 3.2287 - val_y2_output_loss: 11.1416 - val_y1_output_root_mean_squared_error: 1.8284 - val_y2_output_root_mean_squared_error: 3.3850
# Epoch 90/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6332 - y1_output_loss: 0.9897 - y2_output_loss: 2.7152 - y1_output_root_mean_squared_error: 0.9966 - y2_output_root_mean_squared_error: 1.6248 - val_loss: 3.2574 - val_y1_output_loss: 0.8671 - val_y2_output_loss: 2.3131 - val_y1_output_root_mean_squared_error: 0.9388 - val_y2_output_root_mean_squared_error: 1.5414
# Epoch 91/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.8608 - y1_output_loss: 2.1535 - y2_output_loss: 5.6397 - y1_output_root_mean_squared_error: 1.4733 - y2_output_root_mean_squared_error: 2.3854 - val_loss: 3.7078 - val_y1_output_loss: 0.9470 - val_y2_output_loss: 2.6460 - val_y1_output_root_mean_squared_error: 0.9855 - val_y2_output_root_mean_squared_error: 1.6543
# Epoch 92/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8348 - y1_output_loss: 0.6846 - y2_output_loss: 2.1594 - y1_output_root_mean_squared_error: 0.8291 - y2_output_root_mean_squared_error: 1.4654 - val_loss: 5.8283 - val_y1_output_loss: 0.7554 - val_y2_output_loss: 4.9361 - val_y1_output_root_mean_squared_error: 0.8812 - val_y2_output_root_mean_squared_error: 2.2476
# Epoch 93/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4104 - y1_output_loss: 0.7871 - y2_output_loss: 2.5944 - y1_output_root_mean_squared_error: 0.8904 - y2_output_root_mean_squared_error: 1.6179 - val_loss: 4.0024 - val_y1_output_loss: 0.9860 - val_y2_output_loss: 2.8901 - val_y1_output_root_mean_squared_error: 1.0088 - val_y2_output_root_mean_squared_error: 1.7276
# Epoch 94/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6269 - y1_output_loss: 0.8303 - y2_output_loss: 3.1407 - y1_output_root_mean_squared_error: 0.8963 - y2_output_root_mean_squared_error: 1.6803 - val_loss: 82.7973 - val_y1_output_loss: 20.7384 - val_y2_output_loss: 59.9966 - val_y1_output_root_mean_squared_error: 4.6230 - val_y2_output_root_mean_squared_error: 7.8374
# Epoch 95/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.7568 - y1_output_loss: 1.3350 - y2_output_loss: 3.4150 - y1_output_root_mean_squared_error: 1.1597 - y2_output_root_mean_squared_error: 1.8471 - val_loss: 4.0145 - val_y1_output_loss: 0.8452 - val_y2_output_loss: 3.0500 - val_y1_output_root_mean_squared_error: 0.9332 - val_y2_output_root_mean_squared_error: 1.7730
# Epoch 96/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8518 - y1_output_loss: 0.7807 - y2_output_loss: 2.0687 - y1_output_root_mean_squared_error: 0.8765 - y2_output_root_mean_squared_error: 1.4435 - val_loss: 3.6151 - val_y1_output_loss: 0.6677 - val_y2_output_loss: 2.8345 - val_y1_output_root_mean_squared_error: 0.8289 - val_y2_output_root_mean_squared_error: 1.7112
# Epoch 97/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.4259 - y1_output_loss: 0.9603 - y2_output_loss: 2.4699 - y1_output_root_mean_squared_error: 0.9770 - y2_output_root_mean_squared_error: 1.5720 - val_loss: 5.9286 - val_y1_output_loss: 2.2939 - val_y2_output_loss: 3.4288 - val_y1_output_root_mean_squared_error: 1.5413 - val_y2_output_root_mean_squared_error: 1.8850
# Epoch 98/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.7678 - y1_output_loss: 1.1323 - y2_output_loss: 2.6023 - y1_output_root_mean_squared_error: 1.0688 - y2_output_root_mean_squared_error: 1.6204 - val_loss: 2.5924 - val_y1_output_loss: 0.5680 - val_y2_output_loss: 1.9414 - val_y1_output_root_mean_squared_error: 0.7653 - val_y2_output_root_mean_squared_error: 1.4166
# Epoch 99/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.1251 - y1_output_loss: 0.8429 - y2_output_loss: 2.2951 - y1_output_root_mean_squared_error: 0.9225 - y2_output_root_mean_squared_error: 1.5080 - val_loss: 2.9285 - val_y1_output_loss: 0.8616 - val_y2_output_loss: 1.9900 - val_y1_output_root_mean_squared_error: 0.9366 - val_y2_output_root_mean_squared_error: 1.4323
# Epoch 100/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7344 - y1_output_loss: 0.6164 - y2_output_loss: 2.1160 - y1_output_root_mean_squared_error: 0.7854 - y2_output_root_mean_squared_error: 1.4552 - val_loss: 4.2873 - val_y1_output_loss: 1.2495 - val_y2_output_loss: 2.8919 - val_y1_output_root_mean_squared_error: 1.1369 - val_y2_output_root_mean_squared_error: 1.7306
# Epoch 101/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5820 - y1_output_loss: 1.0402 - y2_output_loss: 2.6299 - y1_output_root_mean_squared_error: 1.0096 - y2_output_root_mean_squared_error: 1.6008 - val_loss: 6.9494 - val_y1_output_loss: 1.4911 - val_y2_output_loss: 5.3554 - val_y1_output_root_mean_squared_error: 1.2299 - val_y2_output_root_mean_squared_error: 2.3317
# Epoch 102/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.7110 - y1_output_loss: 0.5780 - y2_output_loss: 2.1097 - y1_output_root_mean_squared_error: 0.7639 - y2_output_root_mean_squared_error: 1.4586 - val_loss: 2.8926 - val_y1_output_loss: 0.6680 - val_y2_output_loss: 2.1331 - val_y1_output_root_mean_squared_error: 0.8297 - val_y2_output_root_mean_squared_error: 1.4847
# Epoch 103/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6325 - y1_output_loss: 0.6048 - y2_output_loss: 2.0041 - y1_output_root_mean_squared_error: 0.7811 - y2_output_root_mean_squared_error: 1.4221 - val_loss: 2.6536 - val_y1_output_loss: 0.6063 - val_y2_output_loss: 1.9514 - val_y1_output_root_mean_squared_error: 0.7920 - val_y2_output_root_mean_squared_error: 1.4235
# Epoch 104/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.0587 - y1_output_loss: 0.7700 - y2_output_loss: 2.2870 - y1_output_root_mean_squared_error: 0.8793 - y2_output_root_mean_squared_error: 1.5118 - val_loss: 4.9693 - val_y1_output_loss: 0.6869 - val_y2_output_loss: 4.1342 - val_y1_output_root_mean_squared_error: 0.8331 - val_y2_output_root_mean_squared_error: 2.0677
# Epoch 105/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.2233 - y1_output_loss: 0.5322 - y2_output_loss: 1.7006 - y1_output_root_mean_squared_error: 0.7216 - y2_output_root_mean_squared_error: 1.3048 - val_loss: 3.3013 - val_y1_output_loss: 0.9201 - val_y2_output_loss: 2.2728 - val_y1_output_root_mean_squared_error: 0.9741 - val_y2_output_root_mean_squared_error: 1.5338
# Epoch 106/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.7320 - y1_output_loss: 0.7003 - y2_output_loss: 2.0453 - y1_output_root_mean_squared_error: 0.8371 - y2_output_root_mean_squared_error: 1.4252 - val_loss: 6.9737 - val_y1_output_loss: 2.2220 - val_y2_output_loss: 4.5878 - val_y1_output_root_mean_squared_error: 1.5065 - val_y2_output_root_mean_squared_error: 2.1689
# Epoch 107/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.3034 - y1_output_loss: 0.5945 - y2_output_loss: 1.6951 - y1_output_root_mean_squared_error: 0.7730 - y2_output_root_mean_squared_error: 1.3061 - val_loss: 2.4322 - val_y1_output_loss: 0.5689 - val_y2_output_loss: 1.7803 - val_y1_output_root_mean_squared_error: 0.7674 - val_y2_output_root_mean_squared_error: 1.3577
# Epoch 108/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8071 - y1_output_loss: 0.6086 - y2_output_loss: 2.1938 - y1_output_root_mean_squared_error: 0.7752 - y2_output_root_mean_squared_error: 1.4853 - val_loss: 3.9006 - val_y1_output_loss: 0.9092 - val_y2_output_loss: 2.8643 - val_y1_output_root_mean_squared_error: 0.9696 - val_y2_output_root_mean_squared_error: 1.7206
# Epoch 109/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8475 - y1_output_loss: 0.5928 - y2_output_loss: 2.2299 - y1_output_root_mean_squared_error: 0.7727 - y2_output_root_mean_squared_error: 1.5001 - val_loss: 2.4607 - val_y1_output_loss: 0.6224 - val_y2_output_loss: 1.7636 - val_y1_output_root_mean_squared_error: 0.8010 - val_y2_output_root_mean_squared_error: 1.3487
# Epoch 110/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8685 - y1_output_loss: 0.7481 - y2_output_loss: 2.1031 - y1_output_root_mean_squared_error: 0.8666 - y2_output_root_mean_squared_error: 1.4552 - val_loss: 2.3114 - val_y1_output_loss: 0.5504 - val_y2_output_loss: 1.6996 - val_y1_output_root_mean_squared_error: 0.7468 - val_y2_output_root_mean_squared_error: 1.3243
# Epoch 111/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.0822 - y1_output_loss: 1.6353 - y2_output_loss: 4.3928 - y1_output_root_mean_squared_error: 1.2843 - y2_output_root_mean_squared_error: 2.1054 - val_loss: 4.2324 - val_y1_output_loss: 0.6647 - val_y2_output_loss: 3.4313 - val_y1_output_root_mean_squared_error: 0.8295 - val_y2_output_root_mean_squared_error: 1.8826
# Epoch 112/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.5013 - y1_output_loss: 1.0678 - y2_output_loss: 3.3987 - y1_output_root_mean_squared_error: 1.0376 - y2_output_root_mean_squared_error: 1.8506 - val_loss: 2.7878 - val_y1_output_loss: 0.6034 - val_y2_output_loss: 2.0938 - val_y1_output_root_mean_squared_error: 0.7904 - val_y2_output_root_mean_squared_error: 1.4708
# Epoch 113/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.1026 - y1_output_loss: 0.5216 - y2_output_loss: 1.5679 - y1_output_root_mean_squared_error: 0.7253 - y2_output_root_mean_squared_error: 1.2556 - val_loss: 2.1133 - val_y1_output_loss: 0.4699 - val_y2_output_loss: 1.5764 - val_y1_output_root_mean_squared_error: 0.6960 - val_y2_output_root_mean_squared_error: 1.2763
# Epoch 114/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.3059 - y1_output_loss: 0.4649 - y2_output_loss: 1.8898 - y1_output_root_mean_squared_error: 0.6819 - y2_output_root_mean_squared_error: 1.3568 - val_loss: 13.2454 - val_y1_output_loss: 1.3391 - val_y2_output_loss: 11.6986 - val_y1_output_root_mean_squared_error: 1.1668 - val_y2_output_root_mean_squared_error: 3.4473
# Epoch 115/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.2524 - y1_output_loss: 0.8022 - y2_output_loss: 2.4338 - y1_output_root_mean_squared_error: 0.8965 - y2_output_root_mean_squared_error: 1.5648 - val_loss: 2.2891 - val_y1_output_loss: 0.4437 - val_y2_output_loss: 1.7801 - val_y1_output_root_mean_squared_error: 0.6754 - val_y2_output_root_mean_squared_error: 1.3539
# Epoch 116/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.3580 - y1_output_loss: 0.4800 - y2_output_loss: 1.9186 - y1_output_root_mean_squared_error: 0.6941 - y2_output_root_mean_squared_error: 1.3698 - val_loss: 3.4381 - val_y1_output_loss: 0.6072 - val_y2_output_loss: 2.7228 - val_y1_output_root_mean_squared_error: 0.7921 - val_y2_output_root_mean_squared_error: 1.6765
# Epoch 117/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.2924 - y1_output_loss: 0.5251 - y2_output_loss: 1.7848 - y1_output_root_mean_squared_error: 0.7195 - y2_output_root_mean_squared_error: 1.3322 - val_loss: 3.9019 - val_y1_output_loss: 0.5550 - val_y2_output_loss: 3.2214 - val_y1_output_root_mean_squared_error: 0.7534 - val_y2_output_root_mean_squared_error: 1.8260
# Epoch 118/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.4270 - y1_output_loss: 0.6081 - y2_output_loss: 1.8408 - y1_output_root_mean_squared_error: 0.7827 - y2_output_root_mean_squared_error: 1.3470 - val_loss: 4.9960 - val_y1_output_loss: 1.1181 - val_y2_output_loss: 3.7877 - val_y1_output_root_mean_squared_error: 1.0662 - val_y2_output_root_mean_squared_error: 1.9645
# Epoch 119/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.5398 - y1_output_loss: 0.5478 - y2_output_loss: 2.0096 - y1_output_root_mean_squared_error: 0.7406 - y2_output_root_mean_squared_error: 1.4111 - val_loss: 4.0963 - val_y1_output_loss: 0.6036 - val_y2_output_loss: 3.3536 - val_y1_output_root_mean_squared_error: 0.7857 - val_y2_output_root_mean_squared_error: 1.8652
# Epoch 120/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.2611 - y1_output_loss: 0.4798 - y2_output_loss: 1.7616 - y1_output_root_mean_squared_error: 0.6956 - y2_output_root_mean_squared_error: 1.3332 - val_loss: 1.9696 - val_y1_output_loss: 0.5253 - val_y2_output_loss: 1.4042 - val_y1_output_root_mean_squared_error: 0.7265 - val_y2_output_root_mean_squared_error: 1.2008
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3309 - y1_output_loss: 0.1129 - y2_output_loss: 0.2198 - y1_output_root_mean_squared_error: 0.3356 - y2_output_root_mean_squared_error: 0.4673 - val_loss: 1.3791 - val_y1_output_loss: 0.3681 - val_y2_output_loss: 0.9943 - val_y1_output_root_mean_squared_error: 0.6114 - val_y2_output_root_mean_squared_error: 1.0026
# Epoch 462/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3607 - y1_output_loss: 0.1161 - y2_output_loss: 0.2436 - y1_output_root_mean_squared_error: 0.3417 - y2_output_root_mean_squared_error: 0.4939 - val_loss: 0.8307 - val_y1_output_loss: 0.2379 - val_y2_output_loss: 0.5643 - val_y1_output_root_mean_squared_error: 0.4948 - val_y2_output_root_mean_squared_error: 0.7654
# Epoch 463/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2941 - y1_output_loss: 0.1017 - y2_output_loss: 0.1907 - y1_output_root_mean_squared_error: 0.3199 - y2_output_root_mean_squared_error: 0.4379 - val_loss: 0.9516 - val_y1_output_loss: 0.3080 - val_y2_output_loss: 0.6218 - val_y1_output_root_mean_squared_error: 0.5626 - val_y2_output_root_mean_squared_error: 0.7970
# Epoch 464/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3503 - y1_output_loss: 0.1119 - y2_output_loss: 0.2390 - y1_output_root_mean_squared_error: 0.3351 - y2_output_root_mean_squared_error: 0.4878 - val_loss: 0.6704 - val_y1_output_loss: 0.2309 - val_y2_output_loss: 0.4198 - val_y1_output_root_mean_squared_error: 0.4871 - val_y2_output_root_mean_squared_error: 0.6582
# Epoch 465/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2865 - y1_output_loss: 0.1053 - y2_output_loss: 0.1788 - y1_output_root_mean_squared_error: 0.3260 - y2_output_root_mean_squared_error: 0.4245 - val_loss: 0.6553 - val_y1_output_loss: 0.2164 - val_y2_output_loss: 0.4209 - val_y1_output_root_mean_squared_error: 0.4700 - val_y2_output_root_mean_squared_error: 0.6591
# Epoch 466/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4561 - y1_output_loss: 0.1766 - y2_output_loss: 0.2785 - y1_output_root_mean_squared_error: 0.4206 - y2_output_root_mean_squared_error: 0.5285 - val_loss: 0.7818 - val_y1_output_loss: 0.2521 - val_y2_output_loss: 0.5134 - val_y1_output_root_mean_squared_error: 0.5089 - val_y2_output_root_mean_squared_error: 0.7230
# Epoch 467/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3264 - y1_output_loss: 0.1206 - y2_output_loss: 0.2047 - y1_output_root_mean_squared_error: 0.3485 - y2_output_root_mean_squared_error: 0.4527 - val_loss: 0.7328 - val_y1_output_loss: 0.2522 - val_y2_output_loss: 0.4560 - val_y1_output_root_mean_squared_error: 0.5095 - val_y2_output_root_mean_squared_error: 0.6879
# Epoch 468/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2693 - y1_output_loss: 0.1090 - y2_output_loss: 0.1603 - y1_output_root_mean_squared_error: 0.3311 - y2_output_root_mean_squared_error: 0.3997 - val_loss: 0.9772 - val_y1_output_loss: 0.2233 - val_y2_output_loss: 0.7226 - val_y1_output_root_mean_squared_error: 0.4788 - val_y2_output_root_mean_squared_error: 0.8648
# Epoch 469/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2755 - y1_output_loss: 0.0978 - y2_output_loss: 0.1775 - y1_output_root_mean_squared_error: 0.3136 - y2_output_root_mean_squared_error: 0.4209 - val_loss: 0.7700 - val_y1_output_loss: 0.2138 - val_y2_output_loss: 0.5308 - val_y1_output_root_mean_squared_error: 0.4676 - val_y2_output_root_mean_squared_error: 0.7425
# Epoch 470/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2904 - y1_output_loss: 0.1243 - y2_output_loss: 0.1642 - y1_output_root_mean_squared_error: 0.3540 - y2_output_root_mean_squared_error: 0.4062 - val_loss: 1.0235 - val_y1_output_loss: 0.2412 - val_y2_output_loss: 0.7472 - val_y1_output_root_mean_squared_error: 0.4984 - val_y2_output_root_mean_squared_error: 0.8804
# Epoch 471/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3294 - y1_output_loss: 0.1246 - y2_output_loss: 0.2037 - y1_output_root_mean_squared_error: 0.3527 - y2_output_root_mean_squared_error: 0.4528 - val_loss: 1.2575 - val_y1_output_loss: 0.3769 - val_y2_output_loss: 0.8636 - val_y1_output_root_mean_squared_error: 0.6182 - val_y2_output_root_mean_squared_error: 0.9356
# Epoch 472/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3466 - y1_output_loss: 0.1152 - y2_output_loss: 0.2365 - y1_output_root_mean_squared_error: 0.3401 - y2_output_root_mean_squared_error: 0.4806 - val_loss: 1.6571 - val_y1_output_loss: 0.4845 - val_y2_output_loss: 1.1557 - val_y1_output_root_mean_squared_error: 0.7003 - val_y2_output_root_mean_squared_error: 1.0801
# Epoch 473/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3335 - y1_output_loss: 0.1296 - y2_output_loss: 0.2021 - y1_output_root_mean_squared_error: 0.3618 - y2_output_root_mean_squared_error: 0.4502 - val_loss: 0.6952 - val_y1_output_loss: 0.1926 - val_y2_output_loss: 0.4791 - val_y1_output_root_mean_squared_error: 0.4450 - val_y2_output_root_mean_squared_error: 0.7051
# Epoch 474/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3515 - y1_output_loss: 0.1261 - y2_output_loss: 0.2284 - y1_output_root_mean_squared_error: 0.3505 - y2_output_root_mean_squared_error: 0.4782 - val_loss: 0.9765 - val_y1_output_loss: 0.4817 - val_y2_output_loss: 0.4787 - val_y1_output_root_mean_squared_error: 0.6972 - val_y2_output_root_mean_squared_error: 0.7003
# Epoch 475/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.2825 - y1_output_loss: 0.1121 - y2_output_loss: 0.1697 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4119 - val_loss: 0.9528 - val_y1_output_loss: 0.3203 - val_y2_output_loss: 0.6171 - val_y1_output_root_mean_squared_error: 0.5713 - val_y2_output_root_mean_squared_error: 0.7914
# Epoch 476/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.2997 - y1_output_loss: 0.1072 - y2_output_loss: 0.1920 - y1_output_root_mean_squared_error: 0.3264 - y2_output_root_mean_squared_error: 0.4395 - val_loss: 0.7077 - val_y1_output_loss: 0.2927 - val_y2_output_loss: 0.3965 - val_y1_output_root_mean_squared_error: 0.5458 - val_y2_output_root_mean_squared_error: 0.6401
# Epoch 477/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.6183 - y1_output_loss: 0.2018 - y2_output_loss: 0.4124 - y1_output_root_mean_squared_error: 0.4509 - y2_output_root_mean_squared_error: 0.6442 - val_loss: 0.8419 - val_y1_output_loss: 0.2290 - val_y2_output_loss: 0.5851 - val_y1_output_root_mean_squared_error: 0.4860 - val_y2_output_root_mean_squared_error: 0.7783
# Epoch 478/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3327 - y1_output_loss: 0.1219 - y2_output_loss: 0.2241 - y1_output_root_mean_squared_error: 0.3457 - y2_output_root_mean_squared_error: 0.4617 - val_loss: 2.4427 - val_y1_output_loss: 0.5609 - val_y2_output_loss: 1.8867 - val_y1_output_root_mean_squared_error: 0.7458 - val_y2_output_root_mean_squared_error: 1.3735
# Epoch 479/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3341 - y1_output_loss: 0.1121 - y2_output_loss: 0.2197 - y1_output_root_mean_squared_error: 0.3362 - y2_output_root_mean_squared_error: 0.4702 - val_loss: 0.6833 - val_y1_output_loss: 0.2186 - val_y2_output_loss: 0.4417 - val_y1_output_root_mean_squared_error: 0.4745 - val_y2_output_root_mean_squared_error: 0.6769
# Epoch 480/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3540 - y1_output_loss: 0.1259 - y2_output_loss: 0.2290 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.4774 - val_loss: 1.0237 - val_y1_output_loss: 0.2744 - val_y2_output_loss: 0.7202 - val_y1_output_root_mean_squared_error: 0.5314 - val_y2_output_root_mean_squared_error: 0.8610
# Epoch 481/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.0533 - y1_output_loss: 1.0856 - y2_output_loss: 2.9337 - y1_output_root_mean_squared_error: 1.0466 - y2_output_root_mean_squared_error: 1.7199 - val_loss: 0.8939 - val_y1_output_loss: 0.3196 - val_y2_output_loss: 0.5522 - val_y1_output_root_mean_squared_error: 0.5688 - val_y2_output_root_mean_squared_error: 0.7552
# Epoch 482/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3783 - y1_output_loss: 0.1324 - y2_output_loss: 0.2428 - y1_output_root_mean_squared_error: 0.3654 - y2_output_root_mean_squared_error: 0.4947 - val_loss: 0.7233 - val_y1_output_loss: 0.2634 - val_y2_output_loss: 0.4403 - val_y1_output_root_mean_squared_error: 0.5205 - val_y2_output_root_mean_squared_error: 0.6726
# Epoch 483/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4983 - y1_output_loss: 0.1558 - y2_output_loss: 0.3435 - y1_output_root_mean_squared_error: 0.3965 - y2_output_root_mean_squared_error: 0.5840 - val_loss: 0.7545 - val_y1_output_loss: 0.2195 - val_y2_output_loss: 0.5094 - val_y1_output_root_mean_squared_error: 0.4759 - val_y2_output_root_mean_squared_error: 0.7266
# Epoch 484/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2992 - y1_output_loss: 0.1076 - y2_output_loss: 0.1920 - y1_output_root_mean_squared_error: 0.3275 - y2_output_root_mean_squared_error: 0.4381 - val_loss: 0.7393 - val_y1_output_loss: 0.2718 - val_y2_output_loss: 0.4527 - val_y1_output_root_mean_squared_error: 0.5273 - val_y2_output_root_mean_squared_error: 0.6792
# Epoch 485/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3561 - y1_output_loss: 0.1202 - y2_output_loss: 0.2342 - y1_output_root_mean_squared_error: 0.3480 - y2_output_root_mean_squared_error: 0.4847 - val_loss: 0.6201 - val_y1_output_loss: 0.2015 - val_y2_output_loss: 0.4007 - val_y1_output_root_mean_squared_error: 0.4544 - val_y2_output_root_mean_squared_error: 0.6432
# Epoch 486/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3163 - y1_output_loss: 0.1056 - y2_output_loss: 0.2090 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.4583 - val_loss: 0.6547 - val_y1_output_loss: 0.2266 - val_y2_output_loss: 0.4097 - val_y1_output_root_mean_squared_error: 0.4829 - val_y2_output_root_mean_squared_error: 0.6493
# Epoch 487/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2542 - y1_output_loss: 0.1057 - y2_output_loss: 0.1474 - y1_output_root_mean_squared_error: 0.3260 - y2_output_root_mean_squared_error: 0.3846 - val_loss: 0.6548 - val_y1_output_loss: 0.2212 - val_y2_output_loss: 0.4127 - val_y1_output_root_mean_squared_error: 0.4776 - val_y2_output_root_mean_squared_error: 0.6532
# Epoch 488/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3020 - y1_output_loss: 0.1031 - y2_output_loss: 0.1966 - y1_output_root_mean_squared_error: 0.3220 - y2_output_root_mean_squared_error: 0.4453 - val_loss: 0.8027 - val_y1_output_loss: 0.2535 - val_y2_output_loss: 0.5241 - val_y1_output_root_mean_squared_error: 0.5106 - val_y2_output_root_mean_squared_error: 0.7362
# Epoch 489/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3263 - y1_output_loss: 0.1230 - y2_output_loss: 0.2164 - y1_output_root_mean_squared_error: 0.3402 - y2_output_root_mean_squared_error: 0.4588 - val_loss: 1.5116 - val_y1_output_loss: 0.2989 - val_y2_output_loss: 1.1598 - val_y1_output_root_mean_squared_error: 0.5559 - val_y2_output_root_mean_squared_error: 1.0966
# Epoch 490/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4815 - y1_output_loss: 0.1393 - y2_output_loss: 0.3473 - y1_output_root_mean_squared_error: 0.3749 - y2_output_root_mean_squared_error: 0.5839 - val_loss: 1.1276 - val_y1_output_loss: 0.2187 - val_y2_output_loss: 0.8841 - val_y1_output_root_mean_squared_error: 0.4736 - val_y2_output_root_mean_squared_error: 0.9504
# Epoch 491/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.8695 - y1_output_loss: 0.2248 - y2_output_loss: 0.6384 - y1_output_root_mean_squared_error: 0.4760 - y2_output_root_mean_squared_error: 0.8018 - val_loss: 0.8901 - val_y1_output_loss: 0.2812 - val_y2_output_loss: 0.6045 - val_y1_output_root_mean_squared_error: 0.5329 - val_y2_output_root_mean_squared_error: 0.7785
# Epoch 492/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.2784 - y1_output_loss: 0.1109 - y2_output_loss: 0.1806 - y1_output_root_mean_squared_error: 0.3314 - y2_output_root_mean_squared_error: 0.4105 - val_loss: 4.6607 - val_y1_output_loss: 0.5934 - val_y2_output_loss: 3.9789 - val_y1_output_root_mean_squared_error: 0.7812 - val_y2_output_root_mean_squared_error: 2.0126
# Epoch 493/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5637 - y1_output_loss: 0.1689 - y2_output_loss: 0.3914 - y1_output_root_mean_squared_error: 0.4122 - y2_output_root_mean_squared_error: 0.6275 - val_loss: 0.7777 - val_y1_output_loss: 0.2304 - val_y2_output_loss: 0.5230 - val_y1_output_root_mean_squared_error: 0.4857 - val_y2_output_root_mean_squared_error: 0.7361
# Epoch 494/500
# 614/614 [==============================] - 0s 182us/sample - loss: 0.2949 - y1_output_loss: 0.1042 - y2_output_loss: 0.1883 - y1_output_root_mean_squared_error: 0.3242 - y2_output_root_mean_squared_error: 0.4357 - val_loss: 0.6557 - val_y1_output_loss: 0.2147 - val_y2_output_loss: 0.4225 - val_y1_output_root_mean_squared_error: 0.4702 - val_y2_output_root_mean_squared_error: 0.6592
# Epoch 495/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3319 - y1_output_loss: 0.1172 - y2_output_loss: 0.2130 - y1_output_root_mean_squared_error: 0.3435 - y2_output_root_mean_squared_error: 0.4625 - val_loss: 0.6253 - val_y1_output_loss: 0.2207 - val_y2_output_loss: 0.3843 - val_y1_output_root_mean_squared_error: 0.4764 - val_y2_output_root_mean_squared_error: 0.6311
# Epoch 496/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2750 - y1_output_loss: 0.1068 - y2_output_loss: 0.1726 - y1_output_root_mean_squared_error: 0.3237 - y2_output_root_mean_squared_error: 0.4126 - val_loss: 0.8118 - val_y1_output_loss: 0.2943 - val_y2_output_loss: 0.5021 - val_y1_output_root_mean_squared_error: 0.5481 - val_y2_output_root_mean_squared_error: 0.7152
# Epoch 497/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.2784 - y1_output_loss: 0.1126 - y2_output_loss: 0.1645 - y1_output_root_mean_squared_error: 0.3368 - y2_output_root_mean_squared_error: 0.4062 - val_loss: 0.6539 - val_y1_output_loss: 0.2316 - val_y2_output_loss: 0.4005 - val_y1_output_root_mean_squared_error: 0.4890 - val_y2_output_root_mean_squared_error: 0.6441
# Epoch 498/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3434 - y1_output_loss: 0.1119 - y2_output_loss: 0.2333 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.4801 - val_loss: 1.4544 - val_y1_output_loss: 0.3131 - val_y2_output_loss: 1.1026 - val_y1_output_root_mean_squared_error: 0.5682 - val_y2_output_root_mean_squared_error: 1.0638
# Epoch 499/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2835 - y1_output_loss: 0.1056 - y2_output_loss: 0.1809 - y1_output_root_mean_squared_error: 0.3260 - y2_output_root_mean_squared_error: 0.4210 - val_loss: 1.0906 - val_y1_output_loss: 0.2622 - val_y2_output_loss: 0.8118 - val_y1_output_root_mean_squared_error: 0.5168 - val_y2_output_root_mean_squared_error: 0.9075
# Epoch 500/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3137 - y1_output_loss: 0.1130 - y2_output_loss: 0.2023 - y1_output_root_mean_squared_error: 0.3356 - y2_output_root_mean_squared_error: 0.4484 - val_loss: 0.7972 - val_y1_output_loss: 0.2153 - val_y2_output_loss: 0.5559 - val_y1_output_root_mean_squared_error: 0.4691 - val_y2_output_root_mean_squared_error: 0.7597

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 38us/sample - loss: 0.7972 - y1_output_loss: 0.2289 - y2_output_loss: 0.5710 - y1_output_root_mean_squared_error: 0.4691 - y2_output_root_mean_squared_error: 0.7597
# Loss = 0.797222925471021, Y1_loss = 0.22885331511497498, Y1_mse = 0.46905845403671265, Y2_loss = 0.5710124373435974, Y2_mse = 0.759741485118866

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
